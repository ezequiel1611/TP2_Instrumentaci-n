# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %% [markdown]
# Primera señal para el filtro, CH1 entrada, CH2 salida.

# %%
data7 = pd.read_csv("NewFile7.csv", skiprows=1)
data7.drop(data7.columns[3], axis=1, inplace=True)
t = data7.iloc[:,0]*1000
v1 = data7.iloc[:,1]
v2 = data7.iloc[:,2]
# rojo es CH1, azul es CH2
# en las fotos CH1 es amarillo pero no se ve bien con fondo blanco
plt.plot(t,v1,color="red",label="CH1")
plt.plot(t,v2,label="CH2")
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.xlabel("Tiempo (ms)")
plt.ylabel("Voltaje (V)")
plt.title("Senoidal 90Hz, 5Vpp, Offset=0, DC")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Ahora se aumentó la frecuencia de la señal de entrada a 90 KHz

# %%
data8 = pd.read_csv("NewFile8.csv", skiprows=1)
data8.drop(data8.columns[3], axis=1, inplace=True)
t = data8.iloc[:,0]*1000000
v1 = data8.iloc[:,1]
v2 = data8.iloc[:,2]
# rojo es CH1, azul es CH2
plt.plot(t,v1,color="red",label="CH1")
plt.plot(t,v2,label="CH2")
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.xlabel("Tiempo (us)")
plt.ylabel("Voltaje (V)")
plt.title("Senoidal 90KHz, 5Vpp, Offset=0, DC")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Ahora se ajustó la escala de tensión para ver mejor las señales

# %%
data9 = pd.read_csv("NewFile9.csv", skiprows=1)
data9.drop(data9.columns[3], axis=1, inplace=True)
t = data9.iloc[:,0]*1000000
v1 = data9.iloc[:,1]
v2 = data9.iloc[:,2]
# rojo es CH1, azul es CH2
plt.plot(t,v1,color="red",label="CH1")
plt.plot(t,v2,label="CH2")
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.xlabel("Tiempo (us)")
plt.ylabel("Voltaje (V)")
plt.title("Senoidal 90KHz, 5Vpp, Offset=0, DC")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Ahora se configuró el osciloscopio para que promedie la señal.

# %%
data10 = pd.read_csv("NewFile10.csv", skiprows=1)
data10.drop(data10.columns[3], axis=1, inplace=True)
t = data10.iloc[:,0]*1000000
v1 = data10.iloc[:,1]
v2 = data10.iloc[:,2]
# rojo es CH1, azul es CH2
plt.plot(t,v1,color="red",label="CH1")
plt.plot(t,v2,label="CH2")
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.xlabel("Tiempo (us)")
plt.ylabel("Voltaje (V)")
plt.title("Senoidal 90KHz, 5Vpp, Offset=0, DC")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Valores obtenidos usando **Measure** sobre el CH1 con la senoidal de 90Hz:
# 1. 1. V<sub>med</sub> = 20.2mV
# 2. V<sub>pp</sub> = 4.96V
# 3. V<sub>rms</sub> = 1.68V
# 4. freq = 89.3Hz
#
# Valores obtenidos usando **Measure** sobre el CH2 con la senoidal de 90Hz:
# 1. 1. V<sub>med</sub> = 95.6mV
# 2. V<sub>pp</sub> = 4.96V
# 3. V<sub>rms</sub> = 1.68V
# 4. freq = 89.7Hz

# %% [markdown]
# Valores obtenidos usando **cursores** sobre el CH1 con la senoidal de 90Hz:
# 1. V<sub>med</sub> = -80mV
# 2. V<sub>pp</sub> = 4.96V
# 3. V<sub>rms</sub> = $\frac{V_{pp}}{2\sqrt{2}}$ = 1.75V
# 4. freq = 88.7Hz
#
# Valores obtenidos usando **cursores** sobre el CH2 con la senoidal de 90Hz:
# 1. V<sub>med</sub> = -80mV
# 2. V<sub>pp</sub> = 4.96V
# 3. V<sub>rms</sub> = $\frac{V_{pp}}{2\sqrt{2}}$ = 1.75V
# 4. freq = 88.7Hz

# %% [markdown]
# Valores obtenidos por el menú de **Measure** sobre el CH1 con la senoidal de 90KHz:
# 1. V<sub>med</sub> = 80.5mV
# 2. V<sub>pp</sub> = 4.96V
# 3. V<sub>rms</sub> = 1.65V
# 4. freq = 88.97KHz
#
# Valores obtenidos por el menú de **Measure** sobre el CH2 con la senoidal de 90KHz:
# 1. V<sub>med</sub> = 157mV
# 2. V<sub>pp</sub> = 240mV
# 3. V<sub>rms</sub> = 160mV
# 4. freq = NO DATA

# %% [markdown]
# Valores obtenidos usando **cursores** sobre el CH1 con la senoidal de 90KHz:
# 1. V<sub>med</sub> = -40mV
# 2. V<sub>pp</sub> = 5.00V
# 3. V<sub>rms</sub> = $\frac{V_{pp}}{2\sqrt{2}}$ = 1.76V
# 4. freq = 88KHz
#
# Valores obtenidos usando **cursores** sobre el CH2 con la senoidal de 90KHz:
# 1. V<sub>med</sub> = 85.6mV
# 2. V<sub>pp</sub> = 85.6mV
# 3. V<sub>rms</sub> = $\frac{V_{pp}}{2\sqrt{2}}$ = 30.26mV
# 4. freq = 88KHz
